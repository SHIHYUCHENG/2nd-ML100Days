# %% [markdown]
# ## 練習時間
# #### 請寫一個函式用來計算 Mean Square Error
# $ MSE = \frac{1}{n}\sum_{i=1}^{n}{(Y_i - \hat{Y}_i)^2} $
#
# ### Hint: [如何取平方](https://googoodesign.gitbooks.io/-ezpython/unit-1.html)

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
def mean_squared_error(y,yp):
    """
    請完成這個 Function 後往下執行
    """

    """
    計算 MSE
    Args:) / len(y)
    return mse
    """
    mse = MSE = sum((y - yp)**2) / len(y)
    return mse

# %%
w = 3
b = 0.5

x_lin = np.linspace(0, 100, 101)

y = (x_lin + np.random.randn(101) * 5) * w + b

plt.plot(x_lin, y, 'b.', label = 'data points')
plt.title("Assume we have data points")
plt.legend(loc = 2)
plt.show()

# %%
y_hat = x_lin * w + b
plt.plot(x_lin, y, 'b.', label = 'data')
plt.plot(x_lin, y_hat, 'r-', label = 'prediction')
plt.title("Assume we have data points (And the prediction)")
plt.legend(loc = 2)
plt.show()

# %%
# 執行 Function, 確認有沒有正常執行
MSE = mean_squared_error(y, y_hat)

print("The Mean squared error is %.3f" % (MSE))
# Out:
# The Mean squared error is 198.914

# %%
"""
作業1：
請上 Kaggle, 在 Competitions 或 Dataset 中找一組競賽或資料並寫下：
1.	你選的這組資料為何重要
這可以幫助到企業，因為如果成功，系統可用於多種應用，從自動標記聲音的集合，到開發自動標記視頻內容或識別真實發生的聲音事件的系統。
2.	資料從何而來 (tips: 譬如提供者是誰、以什麼方式蒐集)
資料來源於以下音頻片段：
    Freesound Dataset（FSD）：基於使用AudioSet本體組織的Freesound內容在MTG-UPF收集的數據集
    來自Yahoo Flickr Creative Commons 100M數據集（YFCC）的Flickr視頻池的配樂

3.	蒐集而來的資料型態為何
資料型態為非結構的音訊
4.	這組資料想解決的問題如何評估
The novel "label-weighted" part means that the overall score is the average over all the labels in the test set, where each label receives equal weight (by contrast, plain lrap gives each test item equal weight, thereby discounting the contribution of individual labels when they appear on the same item as multiple other labels).
"""

# %%
"""
作業2：
想像你經營一個自由載客車隊，你希望能透過數據分析以提升業績，請你思考並描述你如何規劃整體的分析/解決方案：
1.	核心問題為何 (tips：如何定義 「提升業績 & 你的假設」)
核心問題為提升業績，而業績要好公司口碑一定要好，因此我認為核心問題是乘客搭乘的體驗感想是什麼?
2. 資料從何而來 (tips：哪些資料可能會對你想問的問題產生影響 & 資料如何蒐集)
我認為成的的乘後朋分非常重要，這是可以直接反映出載客品質與乘客內心想法的最佳方式。車內環境、司機態度、開車快慢(會不會繞路或急煞等等)都是評斷標準。而讓乘客在下車透填寫滿意度調查即可獲得數據(可以給點優惠提高填答率)
3.蒐集而來的資料型態為何
為結構化的數值分數
4. 你要回答的問題，其如何評估 (tips：你的假設如何驗證)
根據數值高低，排除極端值並做出分析，且對於弱項進行改進。
"""
